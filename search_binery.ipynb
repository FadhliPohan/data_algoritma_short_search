# %%
import json
import time

# FILE_PATH = "data_pembelian_10000.json"
FILE_PATH = "data_dummy_pelanggan.json"

with open(FILE_PATH, 'r', encoding='utf-8') as file:
    data = json.load(file)

    len(data)

# %%
from operator import itemgetter

# data yang perlu di search
data_by_id = sorted(data, key=itemgetter("id"))
data_by_nama = sorted(data, key=lambda r: r["nama_pelanggan"].lower() )
data_by_tanggal = sorted(data, key=itemgetter("tanggal_pembelian"))
data_by_jumlah = sorted(data, key=itemgetter("jumlah_pembelian"))

# %%
def binary_search(arr, target, keyfunc):
    """
    arr      : list of record
    target   : nilai yang dicari
    keyfunc  : fungsi untuk mengambil 'key' dari record
    return   : index salah satu elemen yang cocok, atau -1 jika tidak ketemu
    """
    left, right = 0, len(arr) - 1

    while left <= right:
        mid = (left + right) // 2
        k = keyfunc(arr[mid])

        if k == target:
            return mid
        elif k < target:
            left = mid + 1
        else:
            right = mid - 1

    return -1

# %%
def collect_all(arr, index, target, keyfunc):
    """
    Mengambil semua record yang key-nya == target di sekitar index hasil binary_search.
    """
    if index == -1:
        return []

    results = []

    # ke kiri
    i = index
    while i >= 0 and keyfunc(arr[i]) == target:
        results.append(arr[i])
        i -= 1
    results.reverse()  # supaya urutan dari kecil ke besar

    # ke kanan
    i = index + 1
    while i < len(arr) and keyfunc(arr[i]) == target:
        results.append(arr[i])
        i += 1

    return results

# %%
def cari_data():
    print("Jenis pencarian yang tersedia:")
    print("1. id")
    print("2. nama")
    print("3. tanggal")
    print("4. jumlah")

    jenis = input("Masukkan jenis pencarian (id/nama/tanggal/jumlah): ").strip().lower()

    if jenis == "id":
        target = input("Masukkan ID (misal: t0001): ").strip()
        arr = data_by_id
        keyfunc = lambda r: r["id"]

    elif jenis == "nama":
        target = input("Masukkan nama pelanggan: ").strip().lower()
        arr = data_by_nama
        keyfunc = lambda r: r["nama_pelanggan"].lower()

    elif jenis == "tanggal":
        # format harus sama dengan di file, misal: 06-03-2023
        target = input("Masukkan tanggal pembelian (dd-mm-yyyy): ").strip()
        arr = data_by_tanggal
        keyfunc = lambda r: r["tanggal_pembelian"]

    elif jenis == "jumlah":
        target = int(input("Masukkan jumlah pembelian (angka): ").strip())
        arr = data_by_jumlah
        keyfunc = lambda r: r["jumlah_pembelian"]

    else:
        print("Jenis pencarian tidak dikenal.")
        return

    # ----- mulai ukur waktu pencarian -----
    start = time.perf_counter()
    idx = binary_search(arr, target, keyfunc)
    elapsed = (time.perf_counter() - start) * 1000  # ms
    # --------------------------------------

    if idx == -1:
        print(f"Data tidak ditemukan. Waktu pencarian: {elapsed:.6f} ms")
    else:
        results = collect_all(arr, idx, target, keyfunc)
        print(f"Ditemukan {len(results)} data. Waktu pencarian: {elapsed:.6f} ms")
        for i, r in enumerate(results, start=1):
            print(f"\nHasil ke-{i}:")
            print(f"  id               : {r['id']}")
            print(f"  nama_pelanggan   : {r['nama_pelanggan']}")
            print(f"  tanggal_pembelian: {r['tanggal_pembelian']}")
            print(f"  jumlah_pembelian : {r['jumlah_pembelian']}")

# %%
cari_data()
# Out:
# Jenis pencarian yang tersedia:
# 1. id
# 2. nama
# 3. tanggal
# 4. jumlah
# Ditemukan 98 data. Waktu pencarian: 0.014200 ms
#
# Hasil ke-1:
#   id               : t0013
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 21-03-2025
#   jumlah_pembelian : 6
#
# Hasil ke-2:
#   id               : t1106
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 05-03-2025
#   jumlah_pembelian : 4
#
# Hasil ke-3:
#   id               : t4279
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-08-2023
#   jumlah_pembelian : 47
#
# Hasil ke-4:
#   id               : t4290
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-02-2023
#   jumlah_pembelian : 40
#
# Hasil ke-5:
#   id               : t7621
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 30-04-2025
#   jumlah_pembelian : 10
#
# Hasil ke-6:
#   id               : t8130
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 31-08-2023
#   jumlah_pembelian : 9
#
# Hasil ke-7:
#   id               : t9196
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 09-10-2024
#   jumlah_pembelian : 21
#
# Hasil ke-8:
#   id               : t11787
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 12-06-2023
#   jumlah_pembelian : 32
#
# Hasil ke-9:
#   id               : t12098
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-01-2025
#   jumlah_pembelian : 47
#
# Hasil ke-10:
#   id               : t12556
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 01-06-2024
#   jumlah_pembelian : 15
#
# Hasil ke-11:
#   id               : t15789
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 17-04-2025
#   jumlah_pembelian : 3
#
# Hasil ke-12:
#   id               : t15997
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 10-07-2023
#   jumlah_pembelian : 38
#
# Hasil ke-13:
#   id               : t16119
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 20-12-2023
#   jumlah_pembelian : 7
#
# Hasil ke-14:
#   id               : t16425
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 04-01-2025
#   jumlah_pembelian : 48
#
# Hasil ke-15:
#   id               : t16488
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-05-2025
#   jumlah_pembelian : 8
#
# Hasil ke-16:
#   id               : t18003
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 04-07-2025
#   jumlah_pembelian : 37
#
# Hasil ke-17:
#   id               : t18444
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 27-04-2025
#   jumlah_pembelian : 46
#
# Hasil ke-18:
#   id               : t18511
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 26-09-2025
#   jumlah_pembelian : 27
#
# Hasil ke-19:
#   id               : t18897
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 17-11-2023
#   jumlah_pembelian : 42
#
# Hasil ke-20:
#   id               : t19694
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 01-09-2025
#   jumlah_pembelian : 41
#
# Hasil ke-21:
#   id               : t19737
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-04-2023
#   jumlah_pembelian : 3
#
# Hasil ke-22:
#   id               : t19966
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 09-07-2023
#   jumlah_pembelian : 31
#
# Hasil ke-23:
#   id               : t20196
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 03-03-2024
#   jumlah_pembelian : 49
#
# Hasil ke-24:
#   id               : t22147
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 12-11-2025
#   jumlah_pembelian : 45
#
# Hasil ke-25:
#   id               : t22659
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 01-09-2023
#   jumlah_pembelian : 20
#
# Hasil ke-26:
#   id               : t23098
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 09-03-2025
#   jumlah_pembelian : 8
#
# Hasil ke-27:
#   id               : t23405
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 25-09-2023
#   jumlah_pembelian : 1
#
# Hasil ke-28:
#   id               : t23833
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 07-05-2023
#   jumlah_pembelian : 26
#
# Hasil ke-29:
#   id               : t23975
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 27-03-2025
#   jumlah_pembelian : 15
#
# Hasil ke-30:
#   id               : t24885
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 07-11-2024
#   jumlah_pembelian : 47
#
# Hasil ke-31:
#   id               : t25214
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 24-09-2024
#   jumlah_pembelian : 6
#
# Hasil ke-32:
#   id               : t25442
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-05-2023
#   jumlah_pembelian : 5
#
# Hasil ke-33:
#   id               : t28602
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-07-2024
#   jumlah_pembelian : 33
#
# Hasil ke-34:
#   id               : t29516
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 31-12-2023
#   jumlah_pembelian : 2
#
# Hasil ke-35:
#   id               : t29536
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 22-03-2024
#   jumlah_pembelian : 27
#
# Hasil ke-36:
#   id               : t30122
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-04-2023
#   jumlah_pembelian : 36
#
# Hasil ke-37:
#   id               : t31922
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 05-05-2024
#   jumlah_pembelian : 35
#
# Hasil ke-38:
#   id               : t32838
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 07-06-2024
#   jumlah_pembelian : 24
#
# Hasil ke-39:
#   id               : t32867
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 26-04-2024
#   jumlah_pembelian : 15
#
# Hasil ke-40:
#   id               : t32891
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 04-11-2025
#   jumlah_pembelian : 22
#
# Hasil ke-41:
#   id               : t32932
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 23-12-2023
#   jumlah_pembelian : 11
#
# Hasil ke-42:
#   id               : t35129
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 27-04-2023
#   jumlah_pembelian : 13
#
# Hasil ke-43:
#   id               : t36064
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 13-10-2024
#   jumlah_pembelian : 36
#
# Hasil ke-44:
#   id               : t36711
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 26-01-2023
#   jumlah_pembelian : 13
#
# Hasil ke-45:
#   id               : t36727
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 22-05-2025
#   jumlah_pembelian : 15
#
# Hasil ke-46:
#   id               : t36878
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 21-04-2025
#   jumlah_pembelian : 25
#
# Hasil ke-47:
#   id               : t37061
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 26-09-2024
#   jumlah_pembelian : 25
#
# Hasil ke-48:
#   id               : t38531
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 10-10-2024
#   jumlah_pembelian : 12
#
# Hasil ke-49:
#   id               : t38594
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 04-06-2023
#   jumlah_pembelian : 25
#
# Hasil ke-50:
#   id               : t40861
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 31-12-2023
#   jumlah_pembelian : 32
#
# Hasil ke-51:
#   id               : t41555
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 10-09-2023
#   jumlah_pembelian : 50
#
# Hasil ke-52:
#   id               : t42677
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 11-12-2024
#   jumlah_pembelian : 37
#
# Hasil ke-53:
#   id               : t43147
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 13-01-2023
#   jumlah_pembelian : 8
#
# Hasil ke-54:
#   id               : t43790
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 10-06-2025
#   jumlah_pembelian : 34
#
# Hasil ke-55:
#   id               : t43979
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 29-06-2023
#   jumlah_pembelian : 41
#
# Hasil ke-56:
#   id               : t44745
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 28-07-2024
#   jumlah_pembelian : 16
#
# Hasil ke-57:
#   id               : t45445
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 13-03-2024
#   jumlah_pembelian : 32
#
# Hasil ke-58:
#   id               : t49247
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 03-09-2023
#   jumlah_pembelian : 24
#
# Hasil ke-59:
#   id               : t50424
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-10-2023
#   jumlah_pembelian : 37
#
# Hasil ke-60:
#   id               : t50570
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 12-03-2025
#   jumlah_pembelian : 22
#
# Hasil ke-61:
#   id               : t51154
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 17-09-2023
#   jumlah_pembelian : 35
#
# Hasil ke-62:
#   id               : t51489
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-10-2023
#   jumlah_pembelian : 39
#
# Hasil ke-63:
#   id               : t52879
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 29-06-2025
#   jumlah_pembelian : 15
#
# Hasil ke-64:
#   id               : t53000
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 27-01-2024
#   jumlah_pembelian : 35
#
# Hasil ke-65:
#   id               : t53540
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 16-07-2025
#   jumlah_pembelian : 26
#
# Hasil ke-66:
#   id               : t57526
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 11-07-2023
#   jumlah_pembelian : 4
#
# Hasil ke-67:
#   id               : t58602
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 21-06-2024
#   jumlah_pembelian : 23
#
# Hasil ke-68:
#   id               : t59278
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 19-05-2025
#   jumlah_pembelian : 4
#
# Hasil ke-69:
#   id               : t59775
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 13-03-2024
#   jumlah_pembelian : 13
#
# Hasil ke-70:
#   id               : t59910
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 13-12-2023
#   jumlah_pembelian : 27
#
# Hasil ke-71:
#   id               : t61368
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 07-11-2024
#   jumlah_pembelian : 49
#
# Hasil ke-72:
#   id               : t62095
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-04-2023
#   jumlah_pembelian : 47
#
# Hasil ke-73:
#   id               : t64745
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 19-09-2025
#   jumlah_pembelian : 13
#
# Hasil ke-74:
#   id               : t64767
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 05-01-2024
#   jumlah_pembelian : 46
#
# Hasil ke-75:
#   id               : t64964
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 05-04-2025
#   jumlah_pembelian : 11
#
# Hasil ke-76:
#   id               : t66732
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 16-08-2023
#   jumlah_pembelian : 18
#
# Hasil ke-77:
#   id               : t68504
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 06-06-2024
#   jumlah_pembelian : 40
#
# Hasil ke-78:
#   id               : t69299
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 21-04-2023
#   jumlah_pembelian : 48
#
# Hasil ke-79:
#   id               : t69836
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 04-01-2023
#   jumlah_pembelian : 48
#
# Hasil ke-80:
#   id               : t71564
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 28-05-2025
#   jumlah_pembelian : 49
#
# Hasil ke-81:
#   id               : t71865
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-09-2025
#   jumlah_pembelian : 29
#
# Hasil ke-82:
#   id               : t72163
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 16-11-2024
#   jumlah_pembelian : 21
#
# Hasil ke-83:
#   id               : t72234
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 14-04-2024
#   jumlah_pembelian : 6
#
# Hasil ke-84:
#   id               : t72982
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 13-06-2024
#   jumlah_pembelian : 39
#
# Hasil ke-85:
#   id               : t74169
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 09-07-2025
#   jumlah_pembelian : 9
#
# Hasil ke-86:
#   id               : t74820
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 16-03-2024
#   jumlah_pembelian : 3
#
# Hasil ke-87:
#   id               : t77274
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 22-11-2023
#   jumlah_pembelian : 49
#
# Hasil ke-88:
#   id               : t79882
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 19-02-2023
#   jumlah_pembelian : 1
#
# Hasil ke-89:
#   id               : t82408
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 18-04-2023
#   jumlah_pembelian : 48
#
# Hasil ke-90:
#   id               : t83579
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 10-04-2025
#   jumlah_pembelian : 15
#
# Hasil ke-91:
#   id               : t83770
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 08-10-2024
#   jumlah_pembelian : 31
#
# Hasil ke-92:
#   id               : t88066
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 31-12-2024
#   jumlah_pembelian : 27
#
# Hasil ke-93:
#   id               : t88704
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 27-08-2025
#   jumlah_pembelian : 1
#
# Hasil ke-94:
#   id               : t91788
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 08-06-2025
#   jumlah_pembelian : 34
#
# Hasil ke-95:
#   id               : t92923
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 25-09-2023
#   jumlah_pembelian : 45
#
# Hasil ke-96:
#   id               : t95211
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 28-10-2023
#   jumlah_pembelian : 16
#
# Hasil ke-97:
#   id               : t97551
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 15-11-2024
#   jumlah_pembelian : 17
#
# Hasil ke-98:
#   id               : t99507
#   nama_pelanggan   : Yoga Sutrisno
#   tanggal_pembelian: 20-07-2025
#   jumlah_pembelian : 2
